# %% [markdown]
# # 03 — Baseline Model Training
# Logistic Regression baseline — Week 5

# %%
import sys
sys.path.insert(0, '..')

from src.models.train import train_baseline_model, save_model

pipeline, metadata, (X_test, y_test) = train_baseline_model()
metadata
# Out:
# 2026-09-08 07:27:53,983 [INFO] Loaded 5000 rows, 18 columns from /home/claude/healthconnect-ml/data/raw/HealthConnect_Appointment_Data.csv
# 2026-09-08 07:27:54,008 [INFO] Dropped 263 rows with outcome 'Cancelled' (5000 -> 4737 rows)
# 2026-09-08 07:27:54,021 [INFO] Training Logistic Regression baseline on 3789 rows
# {'model_type': 'logistic_regression',
#  'hyperparameters': {'C': 1.0,
#   'class_weight': None,
#   'max_iter': 1000,
#   'random_state': 42},
#  'features': ['age',
#   'booking_lead_days',
#   'previous_appointments',
#   'previous_no_shows',
#   'distance_to_clinic_km',
#   'prior_no_show_rate',
#   'gender',
#   'appointment_type',
#   'appointment_day',
#   'appointment_time',
#   'reminder_channel',
#   'lead_time_bucket',
#   'distance_bucket',
#   'is_first_time_patient',
#   'is_weekend_appointment',
#   'reminder_sent_flag'],
#  'target_mapping': {'No-Show': 1, 'Attended': 0},
#  'train_rows': 3789,
#  'test_rows': 948,
#  'random_state': 42,
# ...

# %%
save_model(pipeline, metadata)
# Out:
# 2026-09-08 07:27:54,055 [INFO] Saved model to /home/claude/healthconnect-ml/models/model_v1.joblib
# 2026-09-08 07:27:54,056 [INFO] Saved metadata to /home/claude/healthconnect-ml/models/model_metadata.json

# %% [markdown]
# Model and metadata saved to `../models/model_v1.joblib` and `../models/model_metadata.json`.
